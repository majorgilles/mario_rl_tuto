# %% [markdown]
# # Issue #1 — Complete the PyTorch Mario RL Tutorial
#
# - **Source:** https://docs.pytorch.org/tutorials/intermediate/mario_rl_tutorial.html
# - **Lesson notes:** ../../../lessons/01-complete-mario-rl-tutorial.md
# - **Reading guide:** ../../../readings/01-complete-mario-rl-tutorial.md
# - **Workspace:** ../
# - **GitHub issue:** https://github.com/majorgilles/mario_rl_tuto/issues/1
#
# Use this notebook for exploratory follow-along work. Add code cells as you reproduce the environment setup, preprocessing wrappers, Mario agent, DDQN learning loop, and logging from the original tutorial.
